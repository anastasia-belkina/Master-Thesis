# %%
import pandas as pd
import matplotlib.pyplot as plt
import spacy
import en_core_web_trf

# %%
# Load data
column_names = ["Sentence", "Label"]
df_valid_sen_lab = pd.read_csv('../datasets_cleaned/valid_cleaned.txt', sep='\t', header=None, names=column_names)

# Load Spacy model
nlp = spacy.load("en_core_web_trf")

# %%
# Additional terms for entity extraction
additional_terms = {"person", "man", "woman", "police", "administration", "immigrants",
                   "president", "minister", "senator", "representative", "governor", "mayor", "council", "secretary", "ambassador",
                   "chancellor", "parliamentary"}

# %%
pronouns = {"i", "me", "myself", "you", "yourself", "he", "she", "him", "her", "they", "them", "himself", "herself", "themself"}

# %%
def find_interacting_entities(doc):
    # Define the priority labels for entities to be extracted
    priority_labels = ["PERSON", "NORP", "ORG", "GPE"]
    valid_entities = []

    for label in priority_labels:
        # If we already have two different entities, stop searching
        if len(valid_entities) >= 2:
            if valid_entities[0][2].lower() != valid_entities[1][2].lower(): break # 2 entities cant be the same entities 

        # Extract entities matching the current priority label
        current_entities = [(ent.start_char, ent.end_char, ent.text) for ent in doc.ents if ent.label_ == label]
        valid_entities.extend(current_entities)

        # Additional check for PERSON label: include tokens from additional terms if fewer than 2 entities found
        if label == "PERSON" and len(valid_entities) < 2:
            for token in doc:
                if token.text.lower() in additional_terms:
                    valid_entities.append((token.idx, token.idx + len(token.text), token.text))

        # Additional check after the last label: include tokens from pronouns if fewer than 2 entities found
        if label == "GPE" and len(valid_entities) < 2:
            for token in doc:
                if token.text.lower() in pronouns:
                    valid_entities.append((token.idx, token.idx + len(token.text), token.text))

        # Sort entities by their start position
        valid_entities = sorted(valid_entities, key=lambda x: x[0])

        # Merge adjacent entities
        merged_entities = []
        i = 0
        while i < len(valid_entities):
            current_ent = valid_entities[i]
            j = i + 1
            while j < len(valid_entities) and valid_entities[j][0] <= current_ent[1] + 1:
                current_ent = (current_ent[0], valid_entities[j][1], current_ent[2] + " " + valid_entities[j][2])
                j += 1
            merged_entities.append(current_ent)
            i = j
        valid_entities = merged_entities

    # Return the first two entities if available
    if len(valid_entities) >= 2:
        return valid_entities[:2]
    else:
        return valid_entities



def wrap_selected_entities(text):
    doc = nlp(text)
    entities = find_interacting_entities(doc)
    
    formatted_text = text
    offset = 0
    for ent in entities:
        start, end, ent_text = ent
        start += offset
        end += offset
        formatted_text = formatted_text[:start] + '[' + ent_text + ']' + formatted_text[end:]
        offset += 2  # 2 characters for the added brackets

    # Construct the final formatted text with entity details
    entity_count = len(entities)
    if entity_count == 0:
        formatted_text = formatted_text + "\t" + "0" + "\t" + "None" + "\t" + "None"
    elif entity_count == 1:
        formatted_text = formatted_text + "\t" + "1" + "\t" + entities[0][2] + "\t" + "None"
    else:
        formatted_text = formatted_text + "\t" + "2" + "\t" + entities[0][2] + "\t" + entities[1][2]
    
    return formatted_text

# %%
# Apply the function to the 'Sentence' column with sentence numbering
df_valid_sen_lab['Formatted_Sentence'] = df_valid_sen_lab.apply(lambda row: wrap_selected_entities(row['Sentence']), axis=1)

# %%
# Select the relevant columns
df_valid_Form_sen_lab_sen_lab = df_valid_sen_lab[['Formatted_Sentence', 'Label']]

# Split the 'Formatted_Sentence' column into multiple columns
split_columns = df_valid_Form_sen_lab_sen_lab['Formatted_Sentence'].str.split("\t", expand=True)

# Assign the new columns to the DataFrame and rename them
df_valid_Form_sen_lab_sen_lab["Formatted_Sentence"] = split_columns[0]
df_valid_Form_sen_lab_sen_lab["Num_of_ent"] = split_columns[1].astype(int)
df_valid_Form_sen_lab_sen_lab["Ent_1"] = split_columns[2]
df_valid_Form_sen_lab_sen_lab["Ent_2"] = split_columns[3]

# Select and reorder the final columns
df_valid_Form_sen_lab_sen_lab = df_valid_Form_sen_lab_sen_lab[["Formatted_Sentence", "Ent_1", "Ent_2", "Num_of_ent", "Label"]]

# Save the new dataframe
file_path = '../datasets_new_nered/valid_new_ner.txt'
df_valid_Form_sen_lab_sen_lab.to_csv(file_path, sep='\t', index=False, header=None)
# Out:
# C:\Users\Anastasiia Belkina\AppData\Local\Temp\ipykernel_8892\970514906.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_valid_Form_sen_lab_sen_lab["Formatted_Sentence"] = split_columns[0]

# %%
df_valid_Form_sen_lab_sen_lab
# Out:
#                                      Formatted_Sentence          Ent_1  \
# 0     [Kratz]’s claims would be a lot easier to beli...          Kratz
# 1               [Brussels] attacker [Najim Laachraoui].       Brussels
# 2     The [Conservatives] support is up from 32.4 pe...  Conservatives
# 3     The meeting, put together by Mr. [Trump]’s con...          Trump
# 4     The president's defeat highlighted the difficu...        Mubarak
# ...                                                 ...            ...
# 1456  Mr [Nicholls] said [Gales] had been responsibl...       Nicholls
# 1457  Former [Olympic] cyclist [Chris Boardman] has ...        Olympic
# 1458  NewsCNN invited architect [James Furzer], whos...   James Furzer
# 1459  Lastly, there are major questions as to the su...         Chinas
# 1460  Hell have gotten away with embarrassing the pr...          Trump
#
#                  Ent_2  Num_of_ent  Label
# 0                Avery           2      0
# 1     Najim Laachraoui           2      0
# 2             Liberals           2      0
# 3          Paul Teller           2      0
# 4                Morsi           2      0
# ...                ...         ...    ...
# 1456             Gales           2      1
# 1457    Chris Boardman           2      3
# 1458       Dean Harvey           2      3
# 1459              Farr           2      4
# 1460            Mercer           2      1
#
# [1461 rows x 5 columns]

# %%
# take only those rows, where Num_of_ent = 2
ent = [2]
mask = df_valid_Form_sen_lab_sen_lab['Num_of_ent'].isin(ent)
df_valid_Form_sen_lab_sen_lab_2 = df_valid_Form_sen_lab_sen_lab[mask]
df_valid_Form_sen_lab_sen_lab_2 = df_valid_Form_sen_lab_sen_lab_2.drop(columns=['Num_of_ent'])

# %%
file_path = '../datasets_new_nered_2_ents/valid.txt'
df_valid_Form_sen_lab_sen_lab_2.to_csv(file_path, sep='\t', index=False, header=None)

# %% [markdown]
# **В скольких случаях моя и их разметка различается?**

# %%
df_valid_Form_sen_lab_sen_lab
# Out:
#                                      Formatted_Sentence          Ent_1  \
# 0     [Kratz]’s claims would be a lot easier to beli...          Kratz
# 1               [Brussels] attacker [Najim Laachraoui].       Brussels
# 2     The [Conservatives] support is up from 32.4 pe...  Conservatives
# 3     The meeting, put together by Mr. [Trump]’s con...          Trump
# 4     The president's defeat highlighted the difficu...        Mubarak
# ...                                                 ...            ...
# 1456  Mr [Nicholls] said [Gales] had been responsibl...       Nicholls
# 1457  Former [Olympic] cyclist [Chris Boardman] has ...        Olympic
# 1458  NewsCNN invited architect [James Furzer], whos...   James Furzer
# 1459  Lastly, there are major questions as to the su...         Chinas
# 1460  Hell have gotten away with embarrassing the pr...          Trump
#
#                  Ent_2  Num_of_ent  Label
# 0                Avery           2      0
# 1     Najim Laachraoui           2      0
# 2             Liberals           2      0
# 3          Paul Teller           2      0
# 4                Morsi           2      0
# ...                ...         ...    ...
# 1456             Gales           2      1
# 1457    Chris Boardman           2      3
# 1458       Dean Harvey           2      3
# 1459              Farr           2      4
# 1460            Mercer           2      1
#
# [1461 rows x 5 columns]

# %%
column_names = ["Sentence", "Ent_1", "Ent_2", "Label"]
df_valid_other_ner = pd.read_csv('../dataset/valid.txt', sep='\t', header=None, names=column_names)

# %%
column_names = ["Sentence", "Label"]
df_valid_clean = pd.read_csv('../datasets_cleaned/valid_cleaned.txt', sep='\t', header=None, names=column_names)

# %%
# Create the new DataFrame
df_comparing = pd.DataFrame({
    "sentense_clean": df_valid_clean["Sentence"],
    "my_ent_1": df_valid_Form_sen_lab_sen_lab["Ent_1"],
    "their_ent_1": df_valid_other_ner["Ent_1"],
    "my_ent_2": df_valid_Form_sen_lab_sen_lab["Ent_2"],
    "their_ent_2": df_valid_other_ner["Ent_2"],
    "label": df_valid_clean["Label"]  # Assuming label is the same across DataFrames
})

# Show only rows where entities don't match
df_comparing_wrong = df_comparing[
    (df_comparing["my_ent_1"] != df_comparing["their_ent_1"]) |
    (df_comparing["my_ent_2"] != df_comparing["their_ent_2"])
]

# Show only rows where entities match
df_comparing_right = df_comparing[
    (df_comparing["my_ent_1"] == df_comparing["their_ent_1"]) &
    (df_comparing["my_ent_2"] == df_comparing["their_ent_2"])
]

# %%
df_comparing
# Out:
#                                          sentense_clean       my_ent_1  \
# 0     Kratz’s claims would be a lot easier to believ...          Kratz
# 1                   Brussels attacker Najim Laachraoui.       Brussels
# 2     The Conservatives support is up from 32.4 perc...  Conservatives
# 3     The meeting, put together by Mr. Trump’s conse...          Trump
# 4     The president's defeat highlighted the difficu...        Mubarak
# ...                                                 ...            ...
# 1456  Mr Nicholls said Gales had been responsible fo...       Nicholls
# 1457  Former Olympic cyclist Chris Boardman has sinc...        Olympic
# 1458  NewsCNN invited architect James Furzer, whose ...   James Furzer
# 1459  Lastly, there are major questions as to the su...         Chinas
# 1460  Hell have gotten away with embarrassing the pr...          Trump
#
#          their_ent_1          my_ent_2       their_ent_2  label
# 0             Kratz’             Avery             Avery      0
# 1            Brussel  Najim Laachraoui  Najim Laachraoui      0
# 2       Conservative          Liberals           Liberal      0
# 3        Paul Teller       Paul Teller    Judicial Watch      0
# 4            Mubarak             Morsi             Morsi      0
# ...              ...               ...               ...    ...
# 1456      Mr Nicholl             Gales              Gale      1
# 1457  Chris Boardman    Chris Boardman              Game      3
# 1458    James Furzer       Dean Harvey       Dean Harvey      3
# 1459           China              Farr              Farr      4
# 1460          Mercer            Mercer            Bannon      1
#
# [1461 rows x 6 columns]

# %%
df_comparing_wrong
# Out:
#                                          sentense_clean       my_ent_1  \
# 0     Kratz’s claims would be a lot easier to believ...          Kratz
# 1                   Brussels attacker Najim Laachraoui.       Brussels
# 2     The Conservatives support is up from 32.4 perc...  Conservatives
# 3     The meeting, put together by Mr. Trump’s conse...          Trump
# 5     Addressing his usual crowd in Chicago on Monda...        Chicago
# ...                                                 ...            ...
# 1455  On "Hannity" tonight, Newt Gingrich praised Pr...  Newt Gingrich
# 1456  Mr Nicholls said Gales had been responsible fo...       Nicholls
# 1457  Former Olympic cyclist Chris Boardman has sinc...        Olympic
# 1459  Lastly, there are major questions as to the su...         Chinas
# 1460  Hell have gotten away with embarrassing the pr...          Trump
#
#          their_ent_1          my_ent_2       their_ent_2  label
# 0             Kratz’             Avery             Avery      0
# 1            Brussel  Najim Laachraoui  Najim Laachraoui      0
# 2       Conservative          Liberals           Liberal      0
# 3        Paul Teller       Paul Teller    Judicial Watch      0
# 5            Chicago   President Obama             Obama      0
# ...              ...               ...               ...    ...
# 1455   Newt Gingrich      Donald Trump        Republican      1
# 1456      Mr Nicholl             Gales              Gale      1
# 1457  Chris Boardman    Chris Boardman              Game      3
# 1459           China              Farr              Farr      4
# 1460          Mercer            Mercer            Bannon      1
#
# [1098 rows x 6 columns]

# %%
#df_comparing_wrong.to_csv('df_comparing_wrong_new.csv', index=False)

# %%
df_comparing_right
# Out:
#                                          sentense_clean      my_ent_1  \
# 4     The president's defeat highlighted the difficu...       Mubarak
# 8     Like many people in the UK workforce, he start...            UK
# 9     Advocates who want America’s immigration laws ...  Donald Trump
# 16    US forces occupied the site around 70 years ag...            US
# 18                        : Rubio supporters cheer Jeb!         Rubio
# ...                                                 ...           ...
# 1444  When Ms. Steinem gathered some of the movement...       Steinem
# 1445    Pete was at the event to cheer Megan onBackGrid          Pete
# 1448  Feinstein said he will oppose any deportation ...     Feinstein
# 1449  Erdogan has accused Gulen’s movement of being ...       Erdogan
# 1458  NewsCNN invited architect James Furzer, whose ...  James Furzer
#
#        their_ent_1         my_ent_2      their_ent_2  label
# 4          Mubarak            Morsi            Morsi      0
# 8               UK             Zopa             Zopa      0
# 9     Donald Trump  Nicholas Kulish  Nicholas Kulish      0
# 16              US         Japanese         Japanese      0
# 18           Rubio              Jeb              Jeb      0
# ...            ...              ...              ...    ...
# 1444       Steinem          Friedan          Friedan      4
# 1445          Pete            Megan            Megan      1
# 1448     Feinstein      Joe Giudice      Joe Giudice      1
# 1449       Erdogan            Gulen            Gulen      3
# 1458  James Furzer      Dean Harvey      Dean Harvey      3
#
# [363 rows x 6 columns]

# %% [markdown]
# **Надо умудриться выделить только те, что у нас одинаковые или хотя бы примерно**

# %% [markdown]
# **А теперь надо собрать в 1 файл все эти совпавшие данные**

# %%
# Create the new DataFrame
df_clean_all_same_together = pd.DataFrame({
    "sentense_clean": df_comparing_right["sentense_clean"],
    "my_ent_1": df_comparing_right["my_ent_1"],
    "my_ent_2": df_comparing_right["my_ent_2"],
    "label": df_comparing_right["label"]  # Assuming label is the same across DataFrames
})

# %%
df_clean_all_same_together
# Out:
#                                          sentense_clean      my_ent_1  \
# 4     The president's defeat highlighted the difficu...       Mubarak
# 8     Like many people in the UK workforce, he start...            UK
# 9     Advocates who want America’s immigration laws ...  Donald Trump
# 16    US forces occupied the site around 70 years ag...            US
# 18                        : Rubio supporters cheer Jeb!         Rubio
# ...                                                 ...           ...
# 1444  When Ms. Steinem gathered some of the movement...       Steinem
# 1445    Pete was at the event to cheer Megan onBackGrid          Pete
# 1448  Feinstein said he will oppose any deportation ...     Feinstein
# 1449  Erdogan has accused Gulen’s movement of being ...       Erdogan
# 1458  NewsCNN invited architect James Furzer, whose ...  James Furzer
#
#              my_ent_2  label
# 4               Morsi      0
# 8                Zopa      0
# 9     Nicholas Kulish      0
# 16           Japanese      0
# 18                Jeb      0
# ...               ...    ...
# 1444          Friedan      4
# 1445            Megan      1
# 1448      Joe Giudice      1
# 1449            Gulen      3
# 1458      Dean Harvey      3
#
# [363 rows x 4 columns]

# %% [markdown]
# Надо теперь к нему добавить те данные, которые как будто сошлись

# %%
df = pd.read_csv('kinda_same_indexes.txt', header=None)
# Convert DataFrame to a numpy array
indexes_array = df[0].to_numpy()

# %%
df_comparing_wrong_kinda_same = df_comparing_wrong.iloc[indexes_array][["sentense_clean", "my_ent_1", "my_ent_2", "label"]]
# Concatenate the DataFrames
df_combined = pd.concat([df_clean_all_same_together, df_comparing_wrong_kinda_same], ignore_index=True)

# %%
df_combined
# Out:
#                                         sentense_clean           my_ent_1  \
# 0    The president's defeat highlighted the difficu...            Mubarak
# 1    Like many people in the UK workforce, he start...                 UK
# 2    Advocates who want America’s immigration laws ...       Donald Trump
# 3    US forces occupied the site around 70 years ag...                 US
# 4                        : Rubio supporters cheer Jeb!              Rubio
# ..                                                 ...                ...
# 545  Mesereaus attack on Constand was a striking de...          Mesereaus
# 546  Qatars announcement of plans to boost LNG outp...             Qatars
# 547  But critics, including Stephen Henderson, the ...  Stephen Henderson
# 548  He added that Davis was instead indirectly blo...              Davis
# 549  Lastly, there are major questions as to the su...             Chinas
#
#             my_ent_2  label
# 0              Morsi      0
# 1               Zopa      0
# 2    Nicholas Kulish      0
# 3           Japanese      0
# 4                Jeb      0
# ..               ...    ...
# 545         Constand      3
# 546     Saudi Arabia      2
# 547            DeVos      3
# 548       Bustamante      3
# 549             Farr      4
#
# [550 rows x 4 columns]

# %%
# Shuffle the DataFrame
df_combined = df_combined.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
label_counts = df_combined['label'].value_counts()

# %%
label_counts
# Out:
# label
# 0    305
# 3    145
# 1     66
# 4     22
# 2     12
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Plotting the histogram for the 'label' column
plt.hist(df_combined['label'], bins=range(df_combined['label'].min(), df_combined['label'].max() + 2), edgecolor='black', align='left')

# Adding title and labels
plt.title('Distribution of Labels in df_combined')
plt.xlabel('Label')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
# Save the new dataframe
file_path = '../datasets_only_same_ents_clean/valid_with_scobes.txt'
df_combined.to_csv(file_path, sep='\t', index=False, header=None)
