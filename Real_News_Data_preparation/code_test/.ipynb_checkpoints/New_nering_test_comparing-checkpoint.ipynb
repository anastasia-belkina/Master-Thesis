# %%
import pandas as pd
import matplotlib.pyplot as plt
import spacy
import en_core_web_trf

# %%
# Load data
column_names = ["Sentence", "Label"]
df_test_sen_lab = pd.read_csv('../datasets_cleaned/test_cleaned.txt', sep='\t', header=None, names=column_names)

# Load Spacy model
nlp = spacy.load("en_core_web_trf")

# %%
# Additional terms for entity extraction
additional_terms = {"person", "man", "woman", "police", "administration", "immigrants",
                   "president", "minister", "senator", "representative", "governor", "mayor", "council", "secretary", "ambassador",
                   "chancellor", "parliamentary"}

# %%
pronouns = {"i", "me", "myself", "you", "yourself", "he", "she", "him", "her", "they", "them", "himself", "herself", "themself"}

# %%
def find_interacting_entities(doc):
    # Define the priority labels for entities to be extracted
    priority_labels = ["PERSON", "NORP", "ORG", "GPE"]
    valid_entities = []

    for label in priority_labels:
        # If we already have two different entities, stop searching
        if len(valid_entities) >= 2:
            if valid_entities[0][2].lower() != valid_entities[1][2].lower(): break # 2 entities cant be the same entities 

        # Extract entities matching the current priority label
        current_entities = [(ent.start_char, ent.end_char, ent.text) for ent in doc.ents if ent.label_ == label]
        valid_entities.extend(current_entities)

        # Additional check for PERSON label: include tokens from additional terms if fewer than 2 entities found
        if label == "PERSON" and len(valid_entities) < 2:
            for token in doc:
                if token.text.lower() in additional_terms:
                    valid_entities.append((token.idx, token.idx + len(token.text), token.text))

        # Additional check after the last label: include tokens from pronouns if fewer than 2 entities found
        if label == "GPE" and len(valid_entities) < 2:
            for token in doc:
                if token.text.lower() in pronouns:
                    valid_entities.append((token.idx, token.idx + len(token.text), token.text))

        # Sort entities by their start position
        valid_entities = sorted(valid_entities, key=lambda x: x[0])

        # Merge adjacent entities
        merged_entities = []
        i = 0
        while i < len(valid_entities):
            current_ent = valid_entities[i]
            j = i + 1
            while j < len(valid_entities) and valid_entities[j][0] <= current_ent[1] + 1:
                current_ent = (current_ent[0], valid_entities[j][1], current_ent[2] + " " + valid_entities[j][2])
                j += 1
            merged_entities.append(current_ent)
            i = j
        valid_entities = merged_entities

    # Return the first two entities if available
    if len(valid_entities) >= 2:
        return valid_entities[:2]
    else:
        return valid_entities



def wrap_selected_entities(text):
    doc = nlp(text)
    entities = find_interacting_entities(doc)
    
    formatted_text = text
    offset = 0
    for ent in entities:
        start, end, ent_text = ent
        start += offset
        end += offset
        formatted_text = formatted_text[:start] + '[' + ent_text + ']' + formatted_text[end:]
        offset += 2  # 2 characters for the added brackets

    # Construct the final formatted text with entity details
    entity_count = len(entities)
    if entity_count == 0:
        formatted_text = formatted_text + "\t" + "0" + "\t" + "None" + "\t" + "None"
    elif entity_count == 1:
        formatted_text = formatted_text + "\t" + "1" + "\t" + entities[0][2] + "\t" + "None"
    else:
        formatted_text = formatted_text + "\t" + "2" + "\t" + entities[0][2] + "\t" + entities[1][2]
    
    return formatted_text

# %%
# Apply the function to the 'Sentence' column with sentence numbering
df_test_sen_lab['Formatted_Sentence'] = df_test_sen_lab.apply(lambda row: wrap_selected_entities(row['Sentence']), axis=1)

# %%
# Select the relevant columns
df_test_Form_sen_lab_sen_lab = df_test_sen_lab[['Formatted_Sentence', 'Label']]

# Split the 'Formatted_Sentence' column into multiple columns
split_columns = df_test_Form_sen_lab_sen_lab['Formatted_Sentence'].str.split("\t", expand=True)

# Assign the new columns to the DataFrame and rename them
df_test_Form_sen_lab_sen_lab["Formatted_Sentence"] = split_columns[0]
df_test_Form_sen_lab_sen_lab["Num_of_ent"] = split_columns[1].astype(int)
df_test_Form_sen_lab_sen_lab["Ent_1"] = split_columns[2]
df_test_Form_sen_lab_sen_lab["Ent_2"] = split_columns[3]

# Select and reorder the final columns
df_test_Form_sen_lab_sen_lab = df_test_Form_sen_lab_sen_lab[["Formatted_Sentence", "Ent_1", "Ent_2", "Num_of_ent", "Label"]]

# Save the new dataframe
file_path = '../datasets_new_nered/test_new_ner.txt'
df_test_Form_sen_lab_sen_lab.to_csv(file_path, sep='\t', index=False, header=None)
# Out:
# C:\Users\Anastasiia Belkina\AppData\Local\Temp\ipykernel_14652\3895722579.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_Form_sen_lab_sen_lab["Formatted_Sentence"] = split_columns[0]

# %%
df_test_Form_sen_lab_sen_lab
# Out:
#                                      Formatted_Sentence  \
# 0     ” Breitbart News has now reached out to the [T...
# 1     [Phoebe Nora Mary Prince], 15, committed suici...
# 2     Notably, the department says about 30 emails t...
# 3     [Meacham] was recently featured by the San Die...
# 4     But Portland's city code prohibits persons fro...
# ...                                                 ...
# 1618  The Trump [administration] is likely to start ...
# 1619  Well, we do have challenges, but were not stup...
# 1620  He was also fired from a season of "The Celebr...
# 1621  [The Hong Kong Monetary Authority] started sel...
# 1622  Mr. [Band] and an associate introduced top cor...
#
#                                  Ent_1          Ent_2  Num_of_ent  Label
# 0                                Trump         Ivanka           2      0
# 1              Phoebe Nora Mary Prince  Phoebe Prince           2      0
# 2                                U. S.       Benghazi           2      0
# 3                              Meacham          Trump           2      0
# 4                                 Root         Ashton           2      0
# ...                                ...            ...         ...    ...
# 1618                    administration          Obama           2      3
# 1619                             Trump      president           2      3
# 1620                       "Hulk Hogan          Hogan           2      1
# 1621  The Hong Kong Monetary Authority           U.S.           2      1
# 1622                              Band      president           2      1
#
# [1623 rows x 5 columns]

# %%
# take only those rows, where Num_of_ent = 2
ent = [2]
mask = df_test_Form_sen_lab_sen_lab['Num_of_ent'].isin(ent)
df_test_Form_sen_lab_sen_lab_2 = df_test_Form_sen_lab_sen_lab[mask]
df_test_Form_sen_lab_sen_lab_2 = df_test_Form_sen_lab_sen_lab_2.drop(columns=['Num_of_ent'])

# %%
file_path = '../datasets_new_nered_2_ents/test.txt'
df_test_Form_sen_lab_sen_lab_2.to_csv(file_path, sep='\t', index=False, header=None)

# %% [markdown]
# **В скольких случаях моя и их разметка различается?**

# %%
import pandas as pd
# просто перезагружаем файл, без разметки заново
column_names = ["Formatted_Sentence", "Ent_1", "Ent_2", "Num_of_ent", "Label"]
df_test_Form_sen_lab_sen_lab = pd.read_csv('../datasets_new_nered/test_new_ner.txt', sep='\t', header=None, names=column_names)

# %%
df_test_Form_sen_lab_sen_lab
# Out:
#                                      Formatted_Sentence  \
# 0     ” Breitbart News has now reached out to the [T...
# 1     [Phoebe Nora Mary Prince], 15, committed suici...
# 2     Notably, the department says about 30 emails t...
# 3     [Meacham] was recently featured by the San Die...
# 4     But Portland's city code prohibits persons fro...
# ...                                                 ...
# 1618  The Trump [administration] is likely to start ...
# 1619  Well, we do have challenges, but were not stup...
# 1620  He was also fired from a season of "The Celebr...
# 1621  [The Hong Kong Monetary Authority] started sel...
# 1622  Mr. [Band] and an associate introduced top cor...
#
#                                  Ent_1          Ent_2  Num_of_ent  Label
# 0                                Trump         Ivanka           2      0
# 1              Phoebe Nora Mary Prince  Phoebe Prince           2      0
# 2                                U. S.       Benghazi           2      0
# 3                              Meacham          Trump           2      0
# 4                                 Root         Ashton           2      0
# ...                                ...            ...         ...    ...
# 1618                    administration          Obama           2      3
# 1619                             Trump      president           2      3
# 1620                       "Hulk Hogan          Hogan           2      1
# 1621  The Hong Kong Monetary Authority           U.S.           2      1
# 1622                              Band      president           2      1
#
# [1623 rows x 5 columns]

# %%
column_names = ["Sentence", "Ent_1", "Ent_2", "Label"]
df_test_other_ner = pd.read_csv('../dataset/test.txt', sep='\t', header=None, names=column_names)

# %%
column_names = ["Sentence", "Label"]
df_test_clean = pd.read_csv('../datasets_cleaned/test_cleaned.txt', sep='\t', header=None, names=column_names)

# %%
# Create the new DataFrame
df_comparing = pd.DataFrame({
    "sentense_clean": df_test_Form_sen_lab_sen_lab["Formatted_Sentence"],
    "my_ent_1": df_test_Form_sen_lab_sen_lab["Ent_1"],
    "their_ent_1": df_test_other_ner["Ent_1"],
    "my_ent_2": df_test_Form_sen_lab_sen_lab["Ent_2"],
    "their_ent_2": df_test_other_ner["Ent_2"],
    "label": df_test_clean["Label"]  # Assuming label is the same across DataFrames
})

# Show only rows where entities don't match
df_comparing_wrong = df_comparing[
    (df_comparing["my_ent_1"] != df_comparing["their_ent_1"]) |
    (df_comparing["my_ent_2"] != df_comparing["their_ent_2"])
]

# Show only rows where entities match
df_comparing_right = df_comparing[
    (df_comparing["my_ent_1"] == df_comparing["their_ent_1"]) &
    (df_comparing["my_ent_2"] == df_comparing["their_ent_2"])
]

# %%
df_comparing
# Out:
#                                          sentense_clean  \
# 0     ” Breitbart News has now reached out to the [T...
# 1     [Phoebe Nora Mary Prince], 15, committed suici...
# 2     Notably, the department says about 30 emails t...
# 3     [Meacham] was recently featured by the San Die...
# 4     But Portland's city code prohibits persons fro...
# ...                                                 ...
# 1618  The Trump [administration] is likely to start ...
# 1619  Well, we do have challenges, but were not stup...
# 1620  He was also fired from a season of "The Celebr...
# 1621  [The Hong Kong Monetary Authority] started sel...
# 1622  Mr. [Band] and an associate introduced top cor...
#
#                               my_ent_1                       their_ent_1  \
# 0                                Trump                     Breitbart New
# 1              Phoebe Nora Mary Prince                     Phoebe Prince
# 2                                U. S.                           Notably
# 3                              Meacham                           Meacham
# 4                                 Root                          Portland
# ...                                ...                               ...
# 1618                    administration                             Trump
# 1619                             Trump                  McClatchy-Marist
# 1620                       "Hulk Hogan                             Hogan
# 1621  The Hong Kong Monetary Authority  The Hong Kong Monetary Authority
# 1622                              Band                              Band
#
#            my_ent_2             their_ent_2  label
# 0            Ivanka                   Trump      0
# 1     Phoebe Prince                   Mass.      0
# 2          Benghazi                Benghazi      0
# 3             Trump                   Trump      0
# 4            Ashton          OregonLive.com      0
# ...             ...                     ...    ...
# 1618          Obama                  Obama’      3
# 1619      president                   Trump      3
# 1620          Hogan                   Trump      1
# 1621           U.S.                    U.S.      1
# 1622      president  the Clinton Foundation      1
#
# [1623 rows x 6 columns]

# %%
df_comparing_wrong.iloc[160]
# Out:
# sentense_clean    He emphasized that the [NSA]'s bulk collection...
# my_ent_1                                                        NSA
# their_ent_1                                                     NSA
# my_ent_2                                                  Americans
# their_ent_2                                                American
# label                                                             0
# Name: 193, dtype: object

# %%
#df_comparing_wrong.to_csv('df_comparing_wrong_new.csv', index=False)

# %%
df_comparing_right
# Out:
#                                          sentense_clean  \
# 3     [Meacham] was recently featured by the San Die...
# 10    When the definitive post mortem of this dismal...
# 13    That trend accelerated, resulting in the secto...
# 18     A grand jury in [Houston] investigating under...
# 19    This has enabled [EFK] to double production ea...
# ...                                                 ...
# 1609  In perhaps the least shocking development of t...
# 1610  [Ryan] specifically advocated that the health ...
# 1613  Pakistan has failed to wipe out the sanctuarie...
# 1616  [Schiff], too, called for a congressional inve...
# 1621  [The Hong Kong Monetary Authority] started sel...
#
#                               my_ent_1                       their_ent_1  \
# 3                              Meacham                           Meacham
# 10                          Republican                        Republican
# 13                             Beijing                           Beijing
# 18                             Houston                           Houston
# 19                                 EFK                               EFK
# ...                                ...                               ...
# 1609                      Barack Obama                      Barack Obama
# 1610                              Ryan                              Ryan
# 1613                           Taliban                           Taliban
# 1616                            Schiff                            Schiff
# 1621  The Hong Kong Monetary Authority  The Hong Kong Monetary Authority
#
#                 my_ent_2         their_ent_2  label
# 3                  Trump               Trump      0
# 10            Democratic          Democratic      0
# 13                 China               China      0
# 18    Planned Parenthood  Planned Parenthood      0
# 19                  Katz                Katz      0
# ...                  ...                 ...    ...
# 1609     Hillary Clinton     Hillary Clinton      1
# 1610  Planned Parenthood  Planned Parenthood      3
# 1613                NATO                NATO      3
# 1616               Trump               Trump      3
# 1621                U.S.                U.S.      1
#
# [418 rows x 6 columns]

# %% [markdown]
# **Надо умудриться выделить только те, что у нас одинаковые или хотя бы примерно - в Excel**

# %% [markdown]
# **А теперь надо собрать в 1 файл все эти совпавшие данные**

# %%
# Create the new DataFrame
df_clean_all_same_together = pd.DataFrame({
    "sentense_clean": df_comparing_right["sentense_clean"],
    "my_ent_1": df_comparing_right["my_ent_1"],
    "my_ent_2": df_comparing_right["my_ent_2"],
    "label": df_comparing_right["label"]  # Assuming label is the same across DataFrames
})

# %%
df_clean_all_same_together
# Out:
#                                          sentense_clean  \
# 3     [Meacham] was recently featured by the San Die...
# 10    When the definitive post mortem of this dismal...
# 13    That trend accelerated, resulting in the secto...
# 18     A grand jury in [Houston] investigating under...
# 19    This has enabled [EFK] to double production ea...
# ...                                                 ...
# 1609  In perhaps the least shocking development of t...
# 1610  [Ryan] specifically advocated that the health ...
# 1613  Pakistan has failed to wipe out the sanctuarie...
# 1616  [Schiff], too, called for a congressional inve...
# 1621  [The Hong Kong Monetary Authority] started sel...
#
#                               my_ent_1            my_ent_2  label
# 3                              Meacham               Trump      0
# 10                          Republican          Democratic      0
# 13                             Beijing               China      0
# 18                             Houston  Planned Parenthood      0
# 19                                 EFK                Katz      0
# ...                                ...                 ...    ...
# 1609                      Barack Obama     Hillary Clinton      1
# 1610                              Ryan  Planned Parenthood      3
# 1613                           Taliban                NATO      3
# 1616                            Schiff               Trump      3
# 1621  The Hong Kong Monetary Authority                U.S.      1
#
# [418 rows x 4 columns]

# %% [markdown]
# Надо теперь к нему добавить те данные, которые как будто сошлись

# %%
df = pd.read_csv('kinda_same_indexes.txt', header=None)
# Convert DataFrame to a numpy array
indexes_array = df[0].to_numpy()

# %%
df_comparing_wrong_kinda_same = df_comparing_wrong.iloc[indexes_array][["sentense_clean", "my_ent_1", "my_ent_2", "label"]]

# %%
# Concatenate the DataFrames
df_combined = pd.concat([df_clean_all_same_together, df_comparing_wrong_kinda_same], ignore_index=True)

# %%
df_combined
# Out:
#                                         sentense_clean  \
# 0    [Meacham] was recently featured by the San Die...
# 1    When the definitive post mortem of this dismal...
# 2    That trend accelerated, resulting in the secto...
# 3     A grand jury in [Houston] investigating under...
# 4    This has enabled [EFK] to double production ea...
# ..                                                 ...
# 640  [Piers Morgan] sharply criticized [Meryl Stree...
# 641  The sources, who asked not to be named, said [...
# 642  ” [Nancy Perkins], 64, a retired nurse, says s...
# 643  [Israel], which has previously accused [Hamas]...
# 644  Having rolled to victory on Election Day with ...
#
#                                 my_ent_1              my_ent_2  label
# 0                                Meacham                 Trump      0
# 1                             Republican            Democratic      0
# 2                                Beijing                 China      0
# 3                                Houston    Planned Parenthood      0
# 4                                    EFK                  Katz      0
# ..                                   ...                   ...    ...
# 640                         Piers Morgan  Meryl Streep’s Trump      3
# 641                                Temer             Rousseffs      3
# 642                        Nancy Perkins                 Trump      3
# 643                               Israel                 Hamas      3
# 644  Republican President George W. Bush             Democrats      3
#
# [645 rows x 4 columns]

# %% [markdown]
# Замиксуй их все

# %%
# Shuffle the DataFrame
df_combined = df_combined.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df_combined
# Out:
#                                         sentense_clean         my_ent_1  \
# 0    [Bush II] — released a statement opposing [Don...          Bush II
# 1    after the [Dallas] murders — by blaming “syste...           Dallas
# 2    [Zappos] CEO [Tony Hsieh] has been praised for...           Zappos
# 3    But [Shaffer] and other experts faulted [Clint...          Shaffer
# 4    Kulitta, music composition software written by...      Donya Quick
# ..                                                 ...              ...
# 640  The [NLRB] is considering, for instance, wheth...             NLRB
# 641  A [British] chip maker is finding out that lif...          British
# 642  President [Bush] was at 58 percent,” noted Ms....             Bush
# 643  [Barbro Holmberg], mother of [Woods]' wife Eli...  Barbro Holmberg
# 644  His Tax ReturnsStone isnt the first [Trump] su...            Trump
#
#                   my_ent_2  label
# 0             Donald Trump      3
# 1          White Americans      3
# 2               Tony Hsieh      1
# 3                  Clinton      3
# 4    Johann Sebastian Bach      0
# ..                     ...    ...
# 640        McDonald’s Corp      0
# 641                  Apple      0
# 642                 Pelosi      4
# 643                  Woods      0
# 644                    GOP      0
#
# [645 rows x 4 columns]

# %% [markdown]
# Какое распределение лейблов?

# %%
label_counts = df_combined['label'].value_counts()

# %%
label_counts
# Out:
# label
# 0    352
# 3    175
# 1     78
# 4     25
# 2     15
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Plotting the histogram for the 'label' column
plt.hist(df_combined['label'], bins=range(df_combined['label'].min(), df_combined['label'].max() + 2), edgecolor='black', align='left')

# Adding title and labels
plt.title('Distribution of Labels in df_combined')
plt.xlabel('Label')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# Сохрани в файл

# %%
# Save the new dataframe
file_path = '../datasets_only_same_ents_clean/test_with_scobes.txt'
df_combined.to_csv(file_path, sep='\t', index=False, header=None)
